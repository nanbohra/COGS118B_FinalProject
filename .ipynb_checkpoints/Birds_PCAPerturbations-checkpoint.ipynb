# %%
# In this noteboook
# We will be perturbing the top 3 PCs of the Birds image embeddings
# And reconstructing perturbed images via StableDiffusion 
# In an endeavor to interpret those 3 dimensions and what they encode
# Pipeline designed by Nandini

# %%
# !pip install --upgrade diffusers[torch]
# !pip install diffusers
# !pip install transformers
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: diffusers[torch] in /home/dkulkarni/.local/lib/python3.11/site-packages (0.35.2)
# Requirement already satisfied: importlib_metadata in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (7.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /home/dkulkarni/.local/lib/python3.11/site-packages (from diffusers[torch]) (0.36.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (2024.11.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (0.4.5)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (10.4.0)
# Requirement already satisfied: torch>=1.4 in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (2.2.1+cu121)
# Requirement already satisfied: accelerate>=0.31.0 in /opt/conda/lib/python3.11/site-packages (from diffusers[torch]) (1.1.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.31.0->diffusers[torch]) (24.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.31.0->diffusers[torch]) (5.9.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from accelerate>=0.31.0->diffusers[torch]) (6.0.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers[torch]) (2024.3.1)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers[torch]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers[torch]) (4.11.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/dkulkarni/.local/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers[torch]) (1.2.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.4->diffusers[torch]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4->diffusers[torch]) (12.1.105)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata->diffusers[torch]) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers[torch]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers[torch]) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.4->diffusers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=1.4->diffusers[torch]) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: diffusers in /home/dkulkarni/.local/lib/python3.11/site-packages (0.35.2)
# Requirement already satisfied: importlib_metadata in /opt/conda/lib/python3.11/site-packages (from diffusers) (7.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from diffusers) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.34.0 in /home/dkulkarni/.local/lib/python3.11/site-packages (from diffusers) (0.36.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from diffusers) (0.4.5)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.11/site-packages (from diffusers) (10.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (4.11.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/dkulkarni/.local/lib/python3.11/site-packages (from huggingface-hub>=0.34.0->diffusers) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata->diffusers) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->diffusers) (2024.8.30)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /opt/conda/lib/python3.11/site-packages (4.46.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/dkulkarni/.local/lib/python3.11/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.11/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/dkulkarni/.local/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (2.2.1+cu121)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/conda/lib/python3.11/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /opt/conda/lib/python3.11/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.1.105)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
import os
from pathlib import Path

# %%
import requests
import torch
from PIL import Image
import matplotlib.pyplot as plt
from io import BytesIO
import numpy as np
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
from sklearn.decomposition import PCA
import matplotlib.gridspec as gridspec

# %%
from diffusers import StableUnCLIPImg2ImgPipeline
from transformers import CLIPTextModelWithProjection, CLIPTokenizer
# Out:
# 2025-12-05 01:47:44.058348: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-05 01:47:44.058403: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-05 01:47:44.059710: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-05 01:47:44.066050: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
base_dir = '/home/dkulkarni/'

# %%
# Loading pre-generated CLIP embeddings from THINGS Birds
birds_emb = np.load('birds_emb.npy')

# %%
# We first visualize what each of the original embeddings look like in the PC space where n_components =3
pca_birds = PCA(n_components=3)
birds_pca = pca_birds.fit_transform(birds_emb)

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(birds_pca[:, 0], birds_pca[:, 1], birds_pca[:, 2], alpha=0.6)
ax.set_xlabel('PC1', fontsize=12)
ax.set_ylabel('PC2', fontsize=12)
ax.set_zlabel('PC3', fontsize=12)
ax.set_title('Birds in 3D PC Space', fontsize=14)

plt.show()

# %% [markdown]
# ## Setting up StableUnCLIP (using starter code)

# %%
from tqdm.auto import tqdm
tqdm._instances.clear()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
pipe = StableUnCLIPImg2ImgPipeline.from_pretrained(
    "sd2-community/stable-diffusion-2-1-unclip",
    torch_dtype=torch.float16,
).to(device)

vision_encoder = pipe.image_encoder
# Out:
# Loading pipeline components...:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
recon_pipe = StableUnCLIPImg2ImgPipeline.from_pretrained(
    "sd2-community/stable-diffusion-2-1-unclip", torch_dtype=torch.float32
)
# Out:
# Loading pipeline components...:   0%|          | 0/9 [00:00<?, ?it/s]

# %%
def reconstruct_image_from_embedding(recon_pipe, embedding):
    emb_tensor = torch.from_numpy(embedding).unsqueeze(0).to(
        device=recon_pipe.device, 
        dtype=recon_pipe.image_encoder.dtype
    )
    return recon_pipe(image_embeds=emb_tensor).images[0]

# %% [markdown]
# ## Starting perturbation and reconstruction

# %%
random_idx = np.random.choice(len(birds_emb))
original_emb = birds_emb[random_idx]

print(f"Selected image at index: {random_idx}")
print(f"Embedding shape: {original_emb.shape}")
# Out:
# Selected image at index: 155
# Embedding shape: (1024,)

# %%
def get_all_images_pathlib(root_folder):
    root_path = Path(root_folder)
    images = []
    
    for file_path in root_path.rglob('*'):
        if file_path.suffix.lower() == '.jpg':
            images.append(str(file_path))
    
    return images

# %%
birds_folder = f'{base_dir}COGS118B_FinalProject/Birds'
birds = get_all_images_pathlib(birds_folder)

original_img = birds[random_idx]
print(original_img)
# Out:
# /home/dkulkarni/COGS118B_FinalProject/Birds/vulture/vulture_01b.jpg

# %%
image_path = birds[random_idx]
img = Image.open(image_path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800>

# %% [markdown]
# ## Perturbation along PC1

# %%
pc1_direction = pca_birds.components_[0]

# %%
alphas = [-3, -2.5, -2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5, 2, 2.5, 3]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc1_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC1')
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
#   0%|          | 0/21 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 6
#       4 for i, alpha in enumerate(alphas):
#       5     perturbed_emb = original_emb + alpha * pc1_direction
# ----> 6     reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
#       8     axes[i].imshow(reconstructed)
#       9     axes[i].set_title(f'α = {alpha}')
#
# Cell In[19], line 6, in reconstruct_image_from_embedding(recon_pipe, embedding)
#       1 def reconstruct_image_from_embedding(recon_pipe, embedding):
#       2     emb_tensor = torch.from_numpy(embedding).unsqueeze(0).to(
#       3         device=recon_pipe.device,
#       4         dtype=recon_pipe.image_encoder.dtype
#       5     )
# ----> 6     return recon_pipe(image_embeds=emb_tensor).images[0]
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_unclip_img2img.py:820, in StableUnCLIPImg2ImgPipeline.__call__(self, image, prompt, height, width, num_inference_steps, guidance_scale, negative_prompt, num_images_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, output_type, return_dict, callback, callback_steps, cross_attention_kwargs, noise_level, image_embeds, clip_skip)
#     817 latent_model_input = self.scheduler.scale_model_input(latent_model_input, t)
#     819 # predict the noise residual
# --> 820 noise_pred = self.unet(
#     821     latent_model_input,
#     822     t,
#     823     encoder_hidden_states=prompt_embeds,
#     824     class_labels=image_embeds,
#     825     cross_attention_kwargs=cross_attention_kwargs,
#     826     return_dict=False,
#     827 )[0]
#     829 # perform guidance
#     830 if do_classifier_free_guidance:
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_condition.py:1215, in UNet2DConditionModel.forward(self, sample, timestep, encoder_hidden_states, class_labels, timestep_cond, attention_mask, cross_attention_kwargs, added_cond_kwargs, down_block_additional_residuals, mid_block_additional_residual, down_intrablock_additional_residuals, encoder_attention_mask, return_dict)
#    1212     if is_adapter and len(down_intrablock_additional_residuals) > 0:
#    1213         additional_residuals["additional_residuals"] = down_intrablock_additional_residuals.pop(0)
# -> 1215     sample, res_samples = downsample_block(
#    1216         hidden_states=sample,
#    1217         temb=emb,
#    1218         encoder_hidden_states=encoder_hidden_states,
#    1219         attention_mask=attention_mask,
#    1220         cross_attention_kwargs=cross_attention_kwargs,
#    1221         encoder_attention_mask=encoder_attention_mask,
#    1222         **additional_residuals,
#    1223     )
#    1224 else:
#    1225     sample, res_samples = downsample_block(hidden_states=sample, temb=emb)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_blocks.py:1270, in CrossAttnDownBlock2D.forward(self, hidden_states, temb, encoder_hidden_states, attention_mask, cross_attention_kwargs, encoder_attention_mask, additional_residuals)
#    1268 else:
#    1269     hidden_states = resnet(hidden_states, temb)
# -> 1270     hidden_states = attn(
#    1271         hidden_states,
#    1272         encoder_hidden_states=encoder_hidden_states,
#    1273         cross_attention_kwargs=cross_attention_kwargs,
#    1274         attention_mask=attention_mask,
#    1275         encoder_attention_mask=encoder_attention_mask,
#    1276         return_dict=False,
#    1277     )[0]
#    1279 # apply additional residuals to the output of the last pair of resnet and attention blocks
#    1280 if i == len(blocks) - 1 and additional_residuals is not None:
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/diffusers/models/transformers/transformer_2d.py:427, in Transformer2DModel.forward(self, hidden_states, encoder_hidden_states, timestep, added_cond_kwargs, class_labels, cross_attention_kwargs, attention_mask, encoder_attention_mask, return_dict)
#     416         hidden_states = self._gradient_checkpointing_func(
#     417             block,
#     418             hidden_states,
#    (...)
#     424             class_labels,
#     425         )
#     426     else:
# --> 427         hidden_states = block(
#     428             hidden_states,
#     429             attention_mask=attention_mask,
#     430             encoder_hidden_states=encoder_hidden_states,
#     431             encoder_attention_mask=encoder_attention_mask,
#     432             timestep=timestep,
#     433             cross_attention_kwargs=cross_attention_kwargs,
#     434             class_labels=class_labels,
#     435         )
#     437 # 3. Output
#     438 if self.is_input_continuous:
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/diffusers/models/attention.py:995, in BasicTransformerBlock.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, timestep, cross_attention_kwargs, class_labels, added_cond_kwargs)
#     992 cross_attention_kwargs = cross_attention_kwargs.copy() if cross_attention_kwargs is not None else {}
#     993 gligen_kwargs = cross_attention_kwargs.pop("gligen", None)
# --> 995 attn_output = self.attn1(
#     996     norm_hidden_states,
#     997     encoder_hidden_states=encoder_hidden_states if self.only_cross_attention else None,
#     998     attention_mask=attention_mask,
#     999     **cross_attention_kwargs,
#    1000 )
#    1002 if self.norm_type == "ada_norm_zero":
#    1003     attn_output = gate_msa.unsqueeze(1) * attn_output
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/diffusers/models/attention_processor.py:605, in Attention.forward(self, hidden_states, encoder_hidden_states, attention_mask, **cross_attention_kwargs)
#     600     logger.warning(
#     601         f"cross_attention_kwargs {unused_kwargs} are not expected by {self.processor.__class__.__name__} and will be ignored."
#     602     )
#     603 cross_attention_kwargs = {k: w for k, w in cross_attention_kwargs.items() if k in attn_parameters}
# --> 605 return self.processor(
#     606     self,
#     607     hidden_states,
#     608     encoder_hidden_states=encoder_hidden_states,
#     609     attention_mask=attention_mask,
#     610     **cross_attention_kwargs,
#     611 )
#
# File ~/.local/lib/python3.11/site-packages/diffusers/models/attention_processor.py:2773, in AttnProcessor2_0.__call__(self, attn, hidden_states, encoder_hidden_states, attention_mask, temb, *args, **kwargs)
#    2770 hidden_states = hidden_states.to(query.dtype)
#    2772 # linear proj
# -> 2773 hidden_states = attn.to_out[0](hidden_states)
#    2774 # dropout
#    2775 hidden_states = attn.to_out[1](hidden_states)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/conda/lib/python3.11/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
alphas = [-20, -10, -5, -2, 0, 2, 5, 10, 20]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc1_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC1')
plt.tight_layout()
plt.show()

# %%
alphas = [-50, -20, -10, -5, 0, 5, 10, 20, 50]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc1_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC1')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Perturbation along PC2

# %%
pc2_direction = pca_birds.components_[1]

# %%
alphas = [-3, -2.5, -2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5, 2, 2.5, 3]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc2_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC2')
plt.tight_layout()
plt.show()

# %%
alphas = [-20, -10, -5, -2, 0, 2, 5, 10, 20]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc2_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC2')
plt.tight_layout()
plt.show()

# %%
alphas = [-50, -20, -10, -5, 0, 5, 10, 20, 50]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc2_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC2')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Perturbation along PC3

# %%
pc3_direction = pca_birds.components_[2]

# %%
alphas = [-3, -2.5, -2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5, 2, 2.5, 3]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc3_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC3')
plt.tight_layout()
plt.show()

# %%
alphas = [-20, -10, -5, -2, 0, 2, 5, 10, 20]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc3_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC3')
plt.tight_layout()
plt.show()

# %%
alphas = [-50, -20, -10, -5, 0, 5, 10, 20, 50]
fig, axes = plt.subplots(1, len(alphas), figsize=(20, 3))

for i, alpha in enumerate(alphas):
    perturbed_emb = original_emb + alpha * pc3_direction
    reconstructed = reconstruct_image_from_embedding(recon_pipe, perturbed_emb)
    
    axes[i].imshow(reconstructed)
    axes[i].set_title(f'α = {alpha}')
    axes[i].axis('off')

plt.suptitle('Perturbations along PC3')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualizing Perturbations at a High-level

# %%
# Here we select 5 images randomly and show the results of perturbations using the first 3 PCs over a set of alpha values.

# %%
n_birds = 5  # number of different images to analyze
pcs_indices = [0, 1, 2]

# set 
alphas = [-50, -40, -30, -20, -10, -5, -2, -1, 0, 1, 2, 5, 10, 20, 30, 40, 50]

# %%
# Randomly selecting imgs for perturbation+reconstruction
random_indices = np.random.choice(len(birds_emb), size=n_images, replace=False)

# %%
for img_num, idx in enumerate(random_indices):
    original_emb = birds_emb[idx]
    original_img = Image.open(birds[idx])
    
    fig = plt.figure(figsize=(20, 8))
    
    gs = gridspec.GridSpec(len(pcs_indices) + 1, len(alphas), 
                          height_ratios=[0.9] + [1]*len(pcs_indices),
                          hspace=0.02, wspace=0.02)
    
    ax_orig = fig.add_subplot(gs[0, len(alphas)//2 - 1:len(alphas)//2 + 2])
    ax_orig.imshow(original_img)
    ax_orig.axis('off')
    ax_orig.set_title('Original', fontsize=12, pad=5)
    
    # Creating perturbation grid
    for row, pc_idx in enumerate(pcs_indices):
        pc_direction = pca_birds.components_[pc_idx]
        
        for col, alpha in enumerate(alphas):
            # Perturbing embs
            perturbed_emb = original_emb + alpha * pc_direction
            
            # Reconstructing perturbs imgs
            reconstructed = reconstruct_image_from_embedding(pipe, perturbed_emb)
            
            ax = fig.add_subplot(gs[row + 1, col])
            ax.imshow(reconstructed)
            ax.axis('off')

            if col == 0:
                ax.set_ylabel(f'PC{pc_idx+1}', fontsize=14, rotation=0, labelpad=30)
            if row == 0:
                ax.set_title(f'α={alpha}', fontsize=10)
    
    plt.suptitle(f'Image {img_num+1}: Perturbations along PC1, PC2, PC3', 
                 fontsize=16, y=0.99)
    plt.show()
